# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import sklearn as sk

# %%
df= pd.read_csv('penguins.csv')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df.dropna(inplace=True)

# %%
x=df['bill_depth_mm']
y=df['bill_length_mm']

# %%
plt.plot(x,y)
#ax.set_facecolor("blue")
plt.show()

# %%
# Defining the plotsize
plt.figure(figsize=(15, 20))
 
# Defining the x-axis, the y-axis and the data
# from where the values are to be taken
plots = sns.barplot(x="flipper_length_mm", y="bill_length_mm", data=df)
 
# Setting the x-acis label and its size
plt.xlabel("flipper_length_mm", size=15)
 
# Setting the y-axis label and its size
plt.ylabel("body_mass_g", size=15)
 
# Finallt plotting the graph
plt.show()

# %%
with plt.style.context('dark_background'):
  sns.scatterplot(data = df, x ='bill_depth_mm',y = 'bill_length_mm', hue='species')

# %%
#plt.figure(figsize=(25,13))
sns.scatterplot(data = df, x ='bill_depth_mm',y = 'bill_length_mm', hue='island')
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
df.species.value_counts().plot(kind='pie',autopct='%.5f',figsize=[10,20])
# Out:
# <AxesSubplot:ylabel='species'>

# %%
my_cmap = plt.get_cmap('hsv')
 
# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(x, y, cmap = my_cmap,c = (x+y))
plt.title("simple 3D scatter plot")
fig.colorbar(sctt, ax = ax, shrink = 0.5, aspect = 5)
ax.set_xlabel('X-axis', fontweight ='bold')
ax.set_ylabel('Y-axis', fontweight ='bold')
ax.set_zlabel('z-axis', fontweight ='bold')
ax.set_facecolor("orange")

# show plot
plt.show()

# %%
# importing all the necessary packages
import numpy as np
import matplotlib.pyplot as plt
  
# importing the style package
from matplotlib import style
  
# creating an array of data for plot
data=x
d=x,y
# using the style for the plot

  
# creating a plot
plt.plot(data)
plt.show()
plt.plot(y)
plt.show()
plt.plot(x)
plt.show()

# %%
plt.hist(x,edgecolor="yellow",color='hotpink', bins=5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


figure=plt.figure(figsize=(100,200))

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
x, y 
hist, xedges, yedges = np.histogram2d(x, y, bins=10)

# Construct arrays for the anchor positions of the 16 bars.
xpos, ypos
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0


ax.bar3d(xpos, ypos,zpos, dx, dy, dz, zsort='average',color='red')
ax.set_facecolor("skyblue")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\USER18~1\AppData\Local\Temp/ipykernel_6408/3093377078.py in <module>
#      11
#      12 # Construct arrays for the anchor positions of the 16 bars.
# ---> 13 xpos, ypos
#      14 xpos = xpos.ravel()
#      15 ypos = ypos.ravel()
#
# NameError: name 'xpos' is not defined

# %%
with plt.style.context('dark_background'):
    sns.violinplot( "sex",x, data=df,
               palette=["lightblue", "hotpink"]);
# Out:
# C:\Users\user 18\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
with plt.style.context('dark_background'):
    sns.distplot(x,bins=10,color='hotpink')
# Out:
# C:\Users\user 18\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
s=df[["bill_depth_mm","bill_length_mm"]]
labels=["lenght","depth"]
bplot = ax.boxplot(s,
                     vert=True,  # vertical box alignment
                     patch_artist=True,  # fill with color
                     labels=labels)  # will be used to label x-ticks
plt.show()

# %%
plt.boxplot(s, patch_artist=True,labels=["lenght","depth"])
plt.show()

# %%
fig = plt.figure(figsize = (10, 7))
plt.hist2d(x, y, bins=(700,500), cmap=plt.cm.jet)
plt.show()

# %% [markdown]
# #***stem plots vertical lines from a baseline to the y-coordinate and places a marker at the tip.***#

# %%
plt.stem(x, y)
plt.show()
